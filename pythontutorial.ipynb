# %% [markdown]
# variable type casting

# %%
s=10
n=int(s)

d=5
e=float(d)

age=25
p=str(age)

print(n)
print(e)
print(p)
# Out:
# 10
# 5.0
# 25

# %%
a='agr'
b=2
c=3.6
list=[1,2,3,4]
bool=True
t={1,2,3}
dict={'key':'value'}
print(type(a))
print(type(b))
print(type(c))
print(type(list))
print(type(bool))
print(type(t))
print(type(dict))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'list'>
# <class 'bool'>
# <class 'set'>
# <class 'dict'>

# %% [markdown]
# #Concept of Object Reference
#
# #Let us assign a variable x to value 5.

# %% [markdown]
# #Swapping Two Variables: Using multiple assignments, we can swap the values of two variables without needing a temporary variable.

# %%
a,b=10,5
a,b=b,a
print(a,b)
# Out:
# 5 10

# %% [markdown]
# #  Counting Characters in a String: Assign the results of multiple operations on a string to variables in one line.

# %%
word='python'
length=len(word)
print('the length of word is:',length)
# Out:
# the length of word is: 6

# %%
x = [1, 2, 3]
y = x
y[0] = 99
print(x)
# Out:
# [99, 2, 3]

# %%
# store name age city  display in one line
name = 'harith'
age = 21
city = 'vijayapura'
print(name,age,city)
print("harry\n21\nbijapur")
# Out:
# harith 21 vijayapura
# harry
# 21
# bijapur

# %%
# store two num and display their their sum and difference
a= 10
b=5
sum= a+b
print(sum)

diff=a-b
print(diff)
# Out:
# 15
# 5

# %%
# store a num and display a) same num   b) double the num
a=10
print(a)

print(2*a)
# Out:
# 10
# 20

# %%
# store the price of one item and quantity find the total cost
apple=50
quantity=12
total=(apple*quantity)
print(total)
# Out:
# 600

# %%
# store your birth year and find your current age
birth=2004
age=(2026-2004)
print(age)
# Out:
# 22

# %%
birth=2004
current_year=2026       
age=(current_year-birth)
print(age)
# Out:
# 22

# %%
# Counting Characters in a String: Assign the results of multiple operations on a string to variables in one line.¶
# Counting Characters in a String: Assign the results of multiple operations on a string to variables in one line.

# %%
""" i am multi line comment
so i will be not executed """
# Out:
# ' i am multi line comment\nso i will be not executed '

# %%
print(oct(23)+oct(23))
# Out:
# 0o270o27

# %%
print(~(~2))
# Out:
# 2

# %%
x = input()
y = input()
print(x+5)
# Out:
#  5
#  5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 x = input()
#       2 y = input()
# ----> 3 print(x+5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = int(input())
print(x)
# Out:
#  1.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x = int(input())
#       2 print(x)
#
# ValueError: invalid literal for int() with base 10: '1.5'

# %%
age = int(input("Enter your age: "))
print("You are", age, "years old")
# Out:
# Enter your age:  hi
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 age = int(input("Enter your age: "))
#       2 print("You are", age, "years old")
#
# ValueError: invalid literal for int() with base 10: 'hi'

# %%
import keyword
print("The list of keywords are : ")
print(keyword.kwlist)
# Out:
# The list of keywords are :
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Keywords as Variable Names
#
# If we attempt to use a keyword as a variable, Python will raise a SyntaxError. Let's look at an example:

# %% [markdown]
#  # Keywords vs Identifiers
# Keywords	Identifiers
# Reserved words in Python that have a specific meaning.	Names given to variables, functions, classes, etc.
# Cannot be used as variable names.	Can be used as variable names if not a keyword.
# Examples: if, else, for, while	Examples: x, number, sum, result
# Part of the Python syntax.	User-defined, meaningful names in the code.
# They cannot be redefined or changed.	Can be defined and redefined by the programmer.

# %% [markdown]
# # data types

# %%
a = 50  # int
b = 60.5  # float
c = "Hello World"  # string
d = ["geeks", "for", "geeks"]  # list 
e = ("geeks", "for", "geeks")  # tuple


print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>

# %%
a = ["Geeks", "For", "Geeks"]
print("Accessing element from the list")
print(a[1])
print(a[2])

print("Accessing element using negative indexing")
print(a[-1])
print(a[-3])
# Out:
# Accessing element from the list
# For
# Geeks
# Accessing element using negative indexing
# Geeks
# Geeks

# %%
s1 = set()

s1 = set("geeksand")
print("Set with the use of String: ", s1)

s2 = set(["Geeks", "For", "Geeks"])
print("Set with the use of List: ", s2)
# Out:
# Set with the use of String:  {'d', 'g', 'e', 'k', 's', 'n', 'a'}
# Set with the use of List:  {'Geeks', 'For'}

# %%
set1 = set(["Geeks", "For", "Geeks","harry"]) #Duplicates are removed automatically
print(set1) 

# loop through set
for i in set1:
   print(i, end=" ") #prints elements one by one
  
# check if item exist in set   
print("harry" in set1)
# Out:
# {'Geeks', 'harry', 'For'}
# Geeks harry For True
